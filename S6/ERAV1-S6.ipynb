# %%
from __future__ import print_function
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms

# %%
# !pip install torchsummary
# Out:
# Requirement already satisfied: torchsummary in c:\users\prabhukirang\anaconda3\envs\torchenvpractice\lib\site-packages (1.5.1)

# %%
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")

# %%
torch.manual_seed(1)
batch_size = 128

kwargs = {'num_workers': 1, 'pin_memory': True} if use_cuda else {}
train_loader = torch.utils.data.DataLoader(
    datasets.MNIST('../data', train=True, download=True,
                    transform=transforms.Compose([
                        transforms.ToTensor(),
                        transforms.Normalize((0.1307,), (0.3081,))
                    ])),
    batch_size=batch_size, shuffle=True, **kwargs)

test_loader = torch.utils.data.DataLoader(
    datasets.MNIST('../data', train=False, transform=transforms.Compose([
                        transforms.ToTensor(),
                        transforms.Normalize((0.1307,), (0.3081,))
                    ])),
    batch_size=batch_size, shuffle=True, **kwargs)

# %%
from model import *
from utils import *

model = Net().to(device)
model_summary(model, input_size=(1, 28, 28))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 16, 28, 28]             160
#        BatchNorm2d-2           [-1, 16, 28, 28]              32
#             Conv2d-3           [-1, 16, 28, 28]           2,320
#        BatchNorm2d-4           [-1, 16, 28, 28]              32
#          MaxPool2d-5           [-1, 16, 14, 14]               0
#            Dropout-6           [-1, 16, 14, 14]               0
#             Conv2d-7           [-1, 16, 14, 14]           2,320
#        BatchNorm2d-8           [-1, 16, 14, 14]              32
#             Conv2d-9           [-1, 16, 14, 14]           2,320
#       BatchNorm2d-10           [-1, 16, 14, 14]              32
#            Conv2d-11           [-1, 32, 14, 14]           4,640
#       BatchNorm2d-12           [-1, 32, 14, 14]              64
#         MaxPool2d-13             [-1, 32, 7, 7]               0
#           Dropout-14             [-1, 32, 7, 7]               0
#            Conv2d-15             [-1, 16, 7, 7]           4,624
#       BatchNorm2d-16             [-1, 16, 7, 7]              32
#            Conv2d-17             [-1, 10, 7, 7]             170
#         AvgPool2d-18             [-1, 10, 1, 1]               0
# ================================================================
# Total params: 16,778
# Trainable params: 16,778
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.66
# Params size (MB): 0.06
# Estimated Total Size (MB): 0.73
# ----------------------------------------------------------------
# c:\Users\prabhukirang\Pictures\ERAV1\S6\model.py:39: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   return F.log_softmax(x)

# %%
optimizer = optim.SGD(model.parameters(), lr=0.1, momentum=0.9)

for epoch in range(1, 20):
    print("Epoch : {}".format(epoch))
    train(model, device, train_loader, optimizer, epoch)
    test(model, device, test_loader)
# Out:
# Epoch : 1
# loss=0.03308643400669098 batch_id=468: 100%|██████████| 469/469 [00:20<00:00, 22.95it/s]
# Test set: Average loss: 0.0921, Accuracy: 9712/10000 (97.12%)
#
# Epoch : 2
# loss=0.1284663826227188 batch_id=468: 100%|██████████| 469/469 [00:19<00:00, 23.48it/s]
# Test set: Average loss: 0.0552, Accuracy: 9829/10000 (98.29%)
#
# Epoch : 3
# loss=0.01346265897154808 batch_id=468: 100%|██████████| 469/469 [00:20<00:00, 23.12it/s]
# Test set: Average loss: 0.0371, Accuracy: 9895/10000 (98.95%)
#
# Epoch : 4
# loss=0.020324429497122765 batch_id=468: 100%|██████████| 469/469 [00:20<00:00, 22.66it/s]
# Test set: Average loss: 0.0270, Accuracy: 9906/10000 (99.06%)
#
# Epoch : 5
# loss=0.012743137776851654 batch_id=468: 100%|██████████| 469/469 [00:19<00:00, 24.01it/s]
# Test set: Average loss: 0.0246, Accuracy: 9912/10000 (99.12%)
#
# Epoch : 6
# loss=0.09132679551839828 batch_id=468: 100%|██████████| 469/469 [00:19<00:00, 23.66it/s]
# Test set: Average loss: 0.0295, Accuracy: 9902/10000 (99.02%)
#
# Epoch : 7
# loss=0.021768758073449135 batch_id=468: 100%|██████████| 469/469 [00:20<00:00, 23.33it/s]
# Test set: Average loss: 0.0228, Accuracy: 9930/10000 (99.30%)
#
# Epoch : 8
# loss=0.00239448226056993 batch_id=468: 100%|██████████| 469/469 [00:19<00:00, 23.93it/s]
# Test set: Average loss: 0.0265, Accuracy: 9918/10000 (99.18%)
#
# Epoch : 9
# loss=0.06300204247236252 batch_id=468: 100%|██████████| 469/469 [00:20<00:00, 22.81it/s]
# Test set: Average loss: 0.0299, Accuracy: 9903/10000 (99.03%)
#
# Epoch : 10
# loss=0.004290265496820211 batch_id=468: 100%|██████████| 469/469 [00:19<00:00, 23.80it/s]
# Test set: Average loss: 0.0298, Accuracy: 9908/10000 (99.08%)
#
# Epoch : 11
# loss=0.040071312338113785 batch_id=468: 100%|██████████| 469/469 [00:19<00:00, 24.04it/s]
# Test set: Average loss: 0.0248, Accuracy: 9921/10000 (99.21%)
#
# Epoch : 12
# loss=0.012056506238877773 batch_id=468: 100%|██████████| 469/469 [00:20<00:00, 22.53it/s]
# Test set: Average loss: 0.0182, Accuracy: 9942/10000 (99.42%)
#
# Epoch : 13
# loss=0.0024723901879042387 batch_id=468: 100%|██████████| 469/469 [00:19<00:00, 24.26it/s]
# Test set: Average loss: 0.0207, Accuracy: 9931/10000 (99.31%)
#
# Epoch : 14
# loss=0.06465941667556763 batch_id=468: 100%|██████████| 469/469 [00:19<00:00, 23.58it/s]
# Test set: Average loss: 0.0238, Accuracy: 9926/10000 (99.26%)
#
# Epoch : 15
# loss=0.007924869656562805 batch_id=468: 100%|██████████| 469/469 [00:21<00:00, 21.45it/s]
# Test set: Average loss: 0.0219, Accuracy: 9931/10000 (99.31%)
#
# Epoch : 16
# loss=0.005484898108989 batch_id=468: 100%|██████████| 469/469 [00:21<00:00, 22.31it/s]
# Test set: Average loss: 0.0227, Accuracy: 9931/10000 (99.31%)
#
# Epoch : 17
# loss=0.009557866491377354 batch_id=468: 100%|██████████| 469/469 [00:19<00:00, 24.03it/s]
# Test set: Average loss: 0.0237, Accuracy: 9936/10000 (99.36%)
#
# Epoch : 18
# loss=0.04090774431824684 batch_id=468: 100%|██████████| 469/469 [00:20<00:00, 22.56it/s]
# Test set: Average loss: 0.0257, Accuracy: 9929/10000 (99.29%)
#
# Epoch : 19
# loss=0.03403320536017418 batch_id=468: 100%|██████████| 469/469 [00:19<00:00, 24.21it/s]
# Test set: Average loss: 0.0177, Accuracy: 9950/10000 (99.50%)
